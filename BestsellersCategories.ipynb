# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %matplotlib inline

# %%
dataBestsellers=pd.read_csv("bestsellers with categories.csv")
dataBestsellers
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
items=["Reviews"]

for f in items:
    fig=plt.figure(figsize=(12,4))
    sb.barplot(x="Year", y=f, data=dataBestsellers)
    plt.xticks(rotation=90)
    plt.grid()
    plt.title(f)
    plt.show()

# %%
indexYear=[2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019]

filterNonFiction=dataBestsellers["Genre"]=="Non Fiction"
auxiliaryNonFiction=dataBestsellers[filterNonFiction]
genreNonFiction=auxiliaryNonFiction.groupby("Year")["User Rating"].count()

filterFiction=dataBestsellers["Genre"]=="Fiction"
auxiliaryFiction=dataBestsellers[filterFiction]
genreFiction=auxiliaryFiction.groupby("Year")["User Rating"].count()

generalTable=pd.DataFrame({"Non Fiction":genreNonFiction,"Fiction":genreFiction},index=indexYear)
generalTable.plot(kind="line")##,stacked=True)
plt.show()

# %%
indexYear=[2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019]

filterYear2009=dataBestsellers["Year"]==2009
auxiliaryYear2009=dataBestsellers[filterYear2009]
year2009=auxiliaryYear2009.groupby(["Year","Author"])["Year"].count().nlargest(1)

filterYear2010=dataBestsellers["Year"]==2010
auxiliaryYear2010=dataBestsellers[filterYear2010]
year2010=auxiliaryYear2010.groupby(["Year","Author"])["Year"].count().nlargest(1)

filterYear2011=dataBestsellers["Year"]==2011
auxiliaryYear2011=dataBestsellers[filterYear2011]
year2011=auxiliaryYear2011.groupby(["Year","Author"])["Year"].count().nlargest(1)

filterYear2012=dataBestsellers["Year"]==2012
auxiliaryYear2012=dataBestsellers[filterYear2012]
year2012=auxiliaryYear2012.groupby(["Year","Author"])["Year"].count().nlargest(1)

filterYear2013=dataBestsellers["Year"]==2013
auxiliaryYear2013=dataBestsellers[filterYear2013]
year2013=auxiliaryYear2013.groupby(["Year","Author"])["Year"].count().nlargest(1)

filterYear2014=dataBestsellers["Year"]==2012
auxiliaryYear2014=dataBestsellers[filterYear2014]
year2014=auxiliaryYear2014.groupby(["Year","Author"])["Year"].count().nlargest(1)

filterYear2015=dataBestsellers["Year"]==2015
auxiliaryYear2015=dataBestsellers[filterYear2015]
year2015=auxiliaryYear2015.groupby(["Year","Author"])["Year"].count().nlargest(1)

filterYear2016=dataBestsellers["Year"]==2016
auxiliaryYear2016=dataBestsellers[filterYear2016]
year2016=auxiliaryYear2016.groupby(["Year","Author"])["Year"].count().nlargest(1)

filterYear2017=dataBestsellers["Year"]==2017
auxiliaryYear2017=dataBestsellers[filterYear2017]
year2017=auxiliaryYear2017.groupby(["Year","Author"])["Year"].count().nlargest(1)

filterYear2018=dataBestsellers["Year"]==2018
auxiliaryYear2018=dataBestsellers[filterYear2018]
year2018=auxiliaryYear2018.groupby(["Year","Author"])["Year"].count().nlargest(1)

filterYear2019=dataBestsellers["Year"]==2019
auxiliaryYear2019=dataBestsellers[filterYear2019]
year2019=auxiliaryYear2019.groupby(["Year","Author"])["Year"].count().nlargest(1)

##globalTable=pd.DataFrame({"2009":year2009,"2010":year2010,"2011":year2011,"2012":year2012,"2013":year2013,"2014":year2014,"2015":year2015,"2016":year2016,"2017":year2017,"2018":year2018,"2019":year2019},index=indexYear)
##globalTable

globalTable=[year2009,year2010,year2011,year2012,year2013,year2014,year2015,year2016,year2017,year2018,year2019]
ex=pd.DataFrame(globalTable,index=indexYear)
ex.plot(kind="bar",grid=True)
plt.legend(bbox_to_anchor=(1, 1))
plt.show()

# %%
# Out:
# <AxesSubplot:xlabel='Author'>

# %%
# Out:
# <AxesSubplot:xlabel='Author'>
